# %% [markdown]
# # Train a Deep NN to predict Asset Price returns

# %% [markdown]
# In practice, we need to explore variations of the design options outlined above because we can rarely be sure from the outset which network architecture best suits the data.
#
# In this section, we will explore various options to build a simple feedforward Neural Network to predict asset price returns for a one-day horizon.

# %% [markdown]
# ## Imports & Settings

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline

import os, sys
from ast import literal_eval as make_tuple
from time import time
from pathlib import Path
from itertools import product
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from scipy.stats import spearmanr
import seaborn as sns
from tensorflow.keras.callbacks import TensorBoard, EarlyStopping
import time
import pandas as pd
from pathlib import Path
from scipy.stats import spearmanr
import numpy as np
from sklearn.preprocessing import StandardScaler

from sklearn.preprocessing import StandardScaler

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Conv1D, MaxPooling1D, GlobalAveragePooling1D, BatchNormalization, Activation
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Conv1D, MaxPooling1D, GlobalAveragePooling1D, BatchNormalization, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import Input

# %%
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
if gpu_devices:
    print('Using GPU')
    tf.config.experimental.set_memory_growth(gpu_devices[0], True)
else:
    print('Using CPU')
# Out:
# Using GPU

# %%
project_path = Path(r'C:/Users/flyin/OneDrive/Desktop/autotrade/new/machine-learning-for-trading')
sys.path.append(str(project_path))
from utils import MultipleTimeSeriesCV, format_time

# %%
np.random.seed(42)
sns.set_style('whitegrid')
idx = pd.IndexSlice

# %%
DATA_STORE = '../data/assets.h5'

# %%
results_path = Path('results')
if not results_path.exists():
    results_path.mkdir()
    
checkpoint_path = results_path / 'logs'

# %% [markdown]
# ## Create a stock return series to predict asset price moves

# %% [markdown]
# To develop our trading strategy, we use the daily stock returns for some 995 US stocks for the eight year period from 2010 to 2017, and the features developed in Chapter 12 that include volatility and momentum factors as well as lagged returns with cross-sectional and sectoral rankings.

# %%
# Use the correct path to the data.h5 file
data = pd.read_hdf(r'C:\Users\flyin\OneDrive\Desktop\autotrade\new\machine-learning-for-trading\new\auto_generated_notebooks\feature_engineering_gradient_boosting\data.h5', 'model_data').dropna().sort_index()

# %%
data.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 948443 entries, ('A', Timestamp('2010-04-06 00:00:00')) to ('ZION', Timestamp('2017-09-28 00:00:00'))
# Data columns (total 38 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   dollar_vol       948443 non-null  float64
#  1   dollar_vol_rank  948443 non-null  float64
#  2   rsi              948443 non-null  float64
#  3   bb_high          948443 non-null  float64
#  4   bb_low           948443 non-null  float64
#  5   NATR             948443 non-null  float64
#  6   ATR              948443 non-null  float64
#  7   PPO              948443 non-null  float64
#  8   MACD             948443 non-null  float64
#  9   metadata_sector  948443 non-null  object
#  10  r01              948443 non-null  float64
#  11  r05              948443 non-null  float64
#  12  r10              948443 non-null  float64
#  13  r21              948443 non-null  float64
#  14  r42              948443 non-null  float64
#  15  r63              948443 non-null  float64
#  16  r01dec           948443 non-null  float64
#  17  r05dec           948443 non-null  float64
#  18  r10dec           948443 non-null  float64
#  19  r21dec           948443 non-null  float64
#  20  r42dec           948443 non-null  float64
#  21  r63dec           948443 non-null  float64
#  22  sector           948443 non-null  int64
#  23  r01q_sector      948443 non-null  float64
#  24  r05q_sector      948443 non-null  float64
#  25  r10q_sector      948443 non-null  float64
#  26  r21q_sector      948443 non-null  float64
#  27  r42q_sector      948443 non-null  float64
#  28  r63q_sector      948443 non-null  float64
#  29  r01_fwd          948443 non-null  float64
#  30  r05_fwd          948443 non-null  float64
#  31  r10_fwd          948443 non-null  float64
#  32  r21_fwd          948443 non-null  float64
#  33  r42_fwd          948443 non-null  float64
#  34  r63_fwd          948443 non-null  float64
#  35  year             948443 non-null  int64
#  36  month            948443 non-null  int64
#  37  weekday          948443 non-null  int64
# dtypes: float64(33), int64(4), object(1)
# memory usage: 279.4+ MB

# %%
# Convert 'metadata_sector' to categorical
data['metadata_sector'] = data['metadata_sector'].astype('category')

# List of categorical columns
categoricals = ['year', 'month', 'sector', 'weekday', 'metadata_sector']

# Apply one-hot encoding to the categorical columns
data_encoded = pd.get_dummies(data, columns=categoricals, drop_first=True)

# Now 'data_encoded' is ready to be used in your model training
print(f"Data after one-hot encoding has {data_encoded.shape[1]} columns.")
# Out:
# Data after one-hot encoding has 77 columns.

# %%
outcomes = data.filter(like='fwd').columns.tolist()

# %%
lookahead = 1
outcome= f'r{lookahead:02}_fwd'

# %%
X_cv = data.loc[idx[:, :'2017'], :].drop(outcomes, axis=1)
y_cv = data.loc[idx[:, :'2017'], outcome]

# %%
len(X_cv.index.get_level_values('symbol').unique())
# Out:
# 910

# %%
X_cv.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 948443 entries, ('A', Timestamp('2010-04-06 00:00:00')) to ('ZION', Timestamp('2017-09-28 00:00:00'))
# Data columns (total 32 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   dollar_vol       948443 non-null  float64
#  1   dollar_vol_rank  948443 non-null  float64
#  2   rsi              948443 non-null  float64
#  3   bb_high          948443 non-null  float64
#  4   bb_low           948443 non-null  float64
#  5   NATR             948443 non-null  float64
#  6   ATR              948443 non-null  float64
#  7   PPO              948443 non-null  float64
#  8   MACD             948443 non-null  float64
#  9   metadata_sector  948443 non-null  category
#  10  r01              948443 non-null  float64
#  11  r05              948443 non-null  float64
#  12  r10              948443 non-null  float64
#  13  r21              948443 non-null  float64
#  14  r42              948443 non-null  float64
#  15  r63              948443 non-null  float64
#  16  r01dec           948443 non-null  float64
#  17  r05dec           948443 non-null  float64
#  18  r10dec           948443 non-null  float64
#  19  r21dec           948443 non-null  float64
#  20  r42dec           948443 non-null  float64
#  21  r63dec           948443 non-null  float64
#  22  sector           948443 non-null  int64
#  23  r01q_sector      948443 non-null  float64
#  24  r05q_sector      948443 non-null  float64
#  25  r10q_sector      948443 non-null  float64
#  26  r21q_sector      948443 non-null  float64
#  27  r42q_sector      948443 non-null  float64
#  28  r63q_sector      948443 non-null  float64
#  29  year             948443 non-null  int64
#  30  month            948443 non-null  int64
#  31  weekday          948443 non-null  int64
# dtypes: category(1), float64(27), int64(4)
# memory usage: 229.6+ MB

# %% [markdown]
# ## Automate model generation

# %% [markdown]
# The following `make_model` function illustrates how to flexibly define various architectural elements for the search process. The dense_layers argument defines both the depth and width of the network as a list of integers. We also use dropout for regularization, expressed as a float in the range [0, 1] to define the probability that a given unit will be excluded from a training iteration.

# %%
def make_modern_cnn_model(dense_layers, activation, dropout, input_shape=(43, 1), num_classes=1):
    model = Sequential()
    
    # Input layer for 1D data (e.g., time series, structured data)
    model.add(Input(shape=input_shape))
    
    # First Convolutional Block (Conv1D for 1D data)
    model.add(Conv1D(32, kernel_size=3, padding='same', kernel_initializer='he_uniform'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))  # Modern use of ReLU for CNNs
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(dropout))
    
    # Second Convolutional Block
    model.add(Conv1D(64, kernel_size=3, padding='same', kernel_initializer='he_uniform'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(dropout))
    
    # Third Convolutional Block
    model.add(Conv1D(128, kernel_size=3, padding='same', kernel_initializer='he_uniform'))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Dropout(dropout))
    
    # Global Average Pooling instead of flattening (modern choice for reducing model size)
    model.add(GlobalAveragePooling1D())

    # Fully connected layers (as per your dense_layer_opts)
    for units in dense_layers:
        model.add(Dense(units))
        model.add(Activation(activation))
        model.add(Dropout(dropout))

    # Output layer (for binary classification, you can modify this for multi-class if needed)
    model.add(Dense(num_classes, activation='sigmoid'))  # For binary classification
    
    # Compile the model
    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    
    return model

# %% [markdown]
# ## Cross-validate multiple configurations with TensorFlow

# %% [markdown]
# ### Train-Test Split

# %% [markdown]
# We split the data into a training set for cross-validation, and keep the last 12 months with data as holdout test:

# %%
n_splits = 12
train_period_length=21 * 12 * 4
test_period_length=21 * 3

# %%
cv = MultipleTimeSeriesCV(n_splits=n_splits,
                          train_period_length=train_period_length,
                          test_period_length=test_period_length,
                          lookahead=lookahead)

# %% [markdown]
# ### Define CV Parameters

# %% [markdown]
# Now we just need to define our Keras classifier using the make_model function, set cross-validation (see chapter 6 on The Machine Learning Process and following for the OneStepTimeSeriesSplit), and the parameters that we would like to explore.
#
# We pick several one- and two-layer configurations, relu and tanh activation functions, and different dropout rates. We could also try out different optimizers (but did not run this experiment to limit what is already a computationally intensive effort):

# %%
"""dense_layer_opts = [(16, 8), (32, 16), (32, 32), (64, 32)]
activation_opts = ['tanh']
dropout_opts = [0, .1, .2]"""
# Out:
#   Cell In[186], line 3
#     dropout_opts = [0, .1, .2]""""
#                                  ^
# SyntaxError: unterminated string literal (detected at line 3)

# %%
"""param_grid = list(product(dense_layer_opts, activation_opts, dropout_opts))
np.random.shuffle(param_grid)"""
# Out:
#   Cell In[187], line 2
#     np.random.shuffle(param_grid)""""""
#                                     ^
# SyntaxError: incomplete input

# %%
"""len(param_grid)"""
# Out:
# 'len(param_grid)'

# %% [markdown]
# To trigger the parameter search, we instantiate a GridSearchCV object, define the fit_params that will be passed to the Keras model’s fit method, and provide the training data to the GridSearchCV fit method:

# %%
def get_train_valid_data(X, y, train_idx, test_idx):
    x_train, y_train = X.iloc[train_idx, :], y.iloc[train_idx]
    x_val, y_val = X.iloc[test_idx, :], y.iloc[test_idx]
    return x_train, y_train, x_val, y_val

# %%
# Define callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
tensorboard_log_dir = './logs'
tensorboard = TensorBoard(log_dir=tensorboard_log_dir, histogram_freq=1)

# Before scaling, convert categorical columns to numerical ones using one-hot encoding
X_cv_encoded = pd.get_dummies(X_cv)

# Initialize variables
ic = []
scaler = StandardScaler()

# Loop through parameter grid for hyperparameter tuning
for params in param_grid:
    dense_layers, activation, dropout = params
    for batch_size in [64, 256]:
        print(dense_layers, activation, dropout, batch_size)
        
        # Create directories for checkpoints
        checkpoint_dir = checkpoint_path / str(dense_layers) / activation / str(dropout) / str(batch_size)
        checkpoint_dir.mkdir(parents=True, exist_ok=True)
        
        start_time = time.time()  # Track overall start time
        
        # Cross-validation loop
        for fold, (train_idx, test_idx) in enumerate(cv.split(X_cv_encoded)):  # Use the encoded version here
            # Get train & validation data
            x_train, y_train, x_val, y_val = get_train_valid_data(X_cv_encoded, y_cv, train_idx, test_idx)
            
            # Scale features
            x_train = scaler.fit_transform(x_train)
            x_val = scaler.transform(x_val)
            
            # Reshape for CNN (assuming 1D data)
            x_train = x_train[..., np.newaxis]  # Add a channel dimension
            x_val = x_val[..., np.newaxis]
            
            # Set up dataframes to log results
            preds = y_val.to_frame('actual')
            r = pd.DataFrame(index=y_val.groupby(level='date').size().index)
            
            # Create model based on validation parameters using modernized CNN
            input_shape = (x_train.shape[1], 1)  # Update input shape for CNN
            model = make_modern_cnn_model(dense_layers, activation, dropout, input_shape)
            
            epochs = 50
            for epoch in range(epochs):
                # Track epoch start time
                epoch_start = time.time()
                
                # Train the model for one epoch
                model.fit(x_train,
                          y_train,
                          batch_size=batch_size,
                          epochs=1,  # Train one epoch at a time
                          verbose=0,
                          shuffle=True,
                          validation_data=(x_val, y_val),
                          callbacks=[early_stopping, tensorboard])  # Added TensorBoard and EarlyStopping callbacks
                
                # Save weights after each epoch
                model.save_weights((checkpoint_dir / f'ckpt_{fold}_{epoch}').as_posix())
                
                # Predict and log results
                preds['predicted'] = model.predict(x_val).squeeze()
                r[epoch] = preds.groupby(level='date').apply(lambda x: spearmanr(x['actual'], x['predicted'])[0])
                
                # Calculate time for the epoch
                epoch_time = time.time() - epoch_start
                
                # Estimate ETA (time remaining)
                remaining_epochs = epochs - (epoch + 1)
                eta = epoch_time * remaining_epochs
                eta_str = str(timedelta(seconds=int(eta)))
                
                # Print progress with ETA
                print(f"Epoch {epoch + 1}/{epochs} | Fold {fold + 1} | Epoch time: {epoch_time:.2f}s | ETA: {eta_str}")
            
            # After all epochs, log final performance for the fold (moved outside epoch loop)
            fold_mean = r.mean().mean()  # Overall mean of the correlation
            fold_median = r.median().median()  # Overall median of the correlation

            print(format_time(time.time() - start_time), 
                  f'{fold + 1:02d} | Fold complete | Mean {fold_mean:7.4f} | Median {fold_median:7.4f}')
        
        # Append intermediate results and save to HDF5
        ic.append(r.assign(dense_layers=str(dense_layers), 
                           activation=activation, 
                           dropout=dropout,
                           batch_size=batch_size,
                           fold=fold))
        
        # Save intermediate results to HDF5
        pd.concat(ic).to_hdf(results_path / 'scores.h5', 'ic_by_day')
# Out:
# (64, 32) tanh 0.1 64
# 904/904 [==============================] - 3s 3ms/step
# Epoch 1/50 | Fold 1 | Epoch time: 87.81s | ETA: 1:11:42
# 904/904 [==============================] - 2s 3ms/step
# Epoch 2/50 | Fold 1 | Epoch time: 103.33s | ETA: 1:22:40
# 904/904 [==============================] - 2s 3ms/step
# Epoch 3/50 | Fold 1 | Epoch time: 104.99s | ETA: 1:22:14
# 904/904 [==============================] - 2s 3ms/step
# Epoch 4/50 | Fold 1 | Epoch time: 86.45s | ETA: 1:06:16
# 904/904 [==============================] - 2s 3ms/step
# Epoch 5/50 | Fold 1 | Epoch time: 103.99s | ETA: 1:17:59
# 904/904 [==============================] - 2s 3ms/step
# Epoch 6/50 | Fold 1 | Epoch time: 103.69s | ETA: 1:16:02
# 904/904 [==============================] - 3s 3ms/step
# Epoch 7/50 | Fold 1 | Epoch time: 98.07s | ETA: 1:10:16
# 904/904 [==============================] - 3s 3ms/step
# Epoch 8/50 | Fold 1 | Epoch time: 84.40s | ETA: 0:59:04
# 904/904 [==============================] - 2s 3ms/step
# Epoch 9/50 | Fold 1 | Epoch time: 106.89s | ETA: 1:13:02
# 904/904 [==============================] - 2s 3ms/step
# Epoch 10/50 | Fold 1 | Epoch time: 106.83s | ETA: 1:11:13
# 904/904 [==============================] - 3s 3ms/step
# Epoch 11/50 | Fold 1 | Epoch time: 103.83s | ETA: 1:07:29
# 904/904 [==============================] - 2s 3ms/step
# Epoch 12/50 | Fold 1 | Epoch time: 105.36s | ETA: 1:06:43
# 904/904 [==============================] - 3s 3ms/step
# Epoch 13/50 | Fold
[==============================] - 3s 3ms/step
# Epoch 13/50 | Fold 3 | Epoch time: 105.49s | ETA: 1:05:03
# 943/943 [==============================] - 3s 3ms/step
# Epoch 14/50 | Fold 3 | Epoch time: 104.66s | ETA: 1:02:47
# 943/943 [==============================] - 2s 2ms/step
# Epoch 15/50 | Fold 3 | Epoch time: 70.12s | ETA: 0:40:54
# 943/943 [==============================] - 3s 3ms/step
# Epoch 16/50 | Fold 3 | Epoch time: 81.18s | ETA: 0:46:00
# 943/943 [==============================] - 3s 3ms/step
# Epoch 17/50 | Fold 3 | Epoch time: 102.63s | ETA: 0:56:26
# 943/943 [==============================] - 3s 3ms/step
# Epoch 18/50 | Fold 3 | Epoch time: 105.46s | ETA: 0:56:14
# 943/943 [==============================] - 3s 3ms/step
# Epoch 19/50 | Fold 3 | Epoch time: 102.00s | ETA: 0:52:42
# 943/943 [==============================] - 2s 2ms/step
# Epoch 20/50 | Fold 3 | Epoch time: 104.28s | ETA: 0:52:08
# 943/943 [==============================] - 3s 3ms/step
# Epoch 21/50 | Fold 3 | Epoch time: 102.73s | ETA: 0:49:39
# 943/943 [==============================] - 3s 3ms/step
# Epoch 22/50 | Fold 3 | Epoch time: 105.16s | ETA: 0:49:04
# 943/943 [==============================] - 3s 3ms/step
# Epoch 23/50 | Fold 3 | Epoch time: 101.97s | ETA: 0:45:53
# 943/943 [==============================] - 2s 3ms/step
# Epoch 24/50 | Fold 3 | Epoch time: 102.35s | ETA: 0:44:21
# 943/943 [==============================] - 3s 3ms/step
# Epoch 25/50 | Fold 3 | Epoch time: 103.82s | ETA: 0:43:15
# 943/943 [==============================] - 3s 3ms/step
# Epoch 26/50 | Fold 3 | Epoch time: 101.72s | ETA: 0:40:41
# 943/943 [==============================] - 3s 3ms/step
# Epoch 27/50 | Fold 3 | Epoch time: 93.15s | ETA: 0:35:42
# 943/943 [==============================] - 3s 3ms/step
# Epoch 28/50 | Fold 3 | Epoch time: 102.10s | ETA: 0:37:26
# 943/943 [==============================] - 3s 3ms/step
# Epoch 29/50 | Fold 3 | Epoch time: 100.79s | ETA: 0:35:16
# 943/943 [==============================] - 3s 3ms/step
# Epoch 30/50 | Fold 3 | Epoch time: 105.44s | ETA: 0:35:08
# 943/943 [==============================] - 3s 3ms/step
# Epoch 31/50 | Fold 3 | Epoch time: 106.15s | ETA: 0:33:36
# 943/943 [==============================] - 2s 2ms/step
# Epoch 32/50 | Fold 3 | Epoch time: 105.17s | ETA: 0:31:33
# 943/943 [==============================] - 3s 3ms/step
# Epoch 33/50 | Fold 3 | Epoch time: 106.42s | ETA: 0:30:09
# 943/943 [==============================] - 3s 3ms/step
# Epoch 34/50 | Fold 3 | Epoch time: 103.43s | ETA: 0:27:34
# 943/943 [==============================] - 3s 3ms/step
# Epoch 35/50 | Fold 3 | Epoch time: 100.58s | ETA: 0:25:08
# 943/943 [==============================] - 2s 3ms/step
# Epoch 36/50 | Fold 3 | Epoch time: 91.92s | ETA: 0:21:26
# 943/943 [==============================] - 3s 3ms/step
# Epoch 37/50 | Fold 3 | Epoch time: 100.29s | ETA: 0:21:43
# 943/943 [==============================] - 3s 3ms/step
# Epoch 38/50 | Fold 3 | Epoch time: 98.68s | ETA: 0:19:44
# 943/943 [==============================] - 3s 3ms/step
# Epoch 39/50 | Fold 3 | Epoch time: 101.50s | ETA: 0:18:36
# 943/943 [==============================] - 3s 3ms/step
# Epoch 40/50 | Fold 3 | Epoch time: 91.92s | ETA: 0:15:19
# 943/943 [==============================] - 3s 3ms/step
# Epoch 41/50 | Fold 3 | Epoch time: 100.72s | ETA: 0:15:06
# 943/943 [==============================] - 3s 3ms/step
# Epoch 42/50 | Fold 3 | Epoch time: 103.88s | ETA: 0:13:51
# 943/943 [==============================] - 3s 3ms/step
# Epoch 43/50 | Fold
[==============================] - 3s 3ms/step
# Epoch 43/50 | Fold 4 | Epoch time: 65.90s | ETA: 0:07:41
# 968/968 [==============================] - 3s 3ms/step
# Epoch 44/50 | Fold 4 | Epoch time: 103.55s | ETA: 0:10:21
# 968/968 [==============================] - 3s 3ms/step
# Epoch 45/50 | Fold 4 | Epoch time: 104.82s | ETA: 0:08:44
# 968/968 [==============================] - 3s 3ms/step
# Epoch 46/50 | Fold 4 | Epoch time: 103.10s | ETA: 0:06:52
# 968/968 [==============================] - 3s 3ms/step
# Epoch 47/50 | Fold 4 | Epoch time: 102.16s | ETA: 0:05:06
# 968/968 [==============================] - 3s 3ms/step
# Epoch 48/50 | Fold 4 | Epoch time: 105.57s | ETA: 0:03:31
# 968/968 [==============================] - 3s 3ms/step
# Epoch 49/50 | Fold 4 | Epoch time: 83.73s | ETA: 0:01:23
# 968/968 [==============================] - 2s 2ms/step
# Epoch 50/50 | Fold 4 | Epoch time: 62.25s | ETA: 0:00:00
# 05:29:12 04 | Fold complete | Mean -0.0035 | Median -0.0082
# 938/938 [==============================] - 1s 1ms/step
# Epoch 1/50 | Fold 5 | Epoch time: 58.83s | ETA: 0:48:02
# 938/938 [==============================] - 2s 2ms/step
# Epoch 2/50 | Fold 5 | Epoch time: 50.23s | ETA: 0:40:10
# 938/938 [==============================] - 2s 2ms/step
# Epoch 3/50 | Fold 5 | Epoch time: 50.27s | ETA: 0:39:22
# 938/938 [==============================] - 2s 2ms/step
# Epoch 4/50 | Fold 5 | Epoch time: 49.15s | ETA: 0:37:40
# 938/938 [==============================] - 1s 1ms/step
# Epoch 5/50 | Fold 5 | Epoch time: 51.25s | ETA: 0:38:26
# 938/938 [==============================] - 1s 2ms/step
# Epoch 6/50 | Fold 5 | Epoch time: 53.76s | ETA: 0:39:25
# 938/938 [==============================] - 2s 2ms/step
# Epoch 7/50 | Fold 5 | Epoch time: 61.42s | ETA: 0:44:01
# 938/938 [==============================] - 3s 3ms/step
# Epoch 8/50 | Fold 5 | Epoch time: 102.24s | ETA: 1:11:34
# 938/938 [==============================] - 3s 3ms/step
# Epoch 9/50 | Fold 5 | Epoch time: 105.37s | ETA: 1:12:00
# 938/938 [==============================] - 2s 3ms/step
# Epoch 10/50 | Fold 5 | Epoch time: 90.47s | ETA: 1:00:18
# 938/938 [==============================] - 3s 3ms/step
# Epoch 11/50 | Fold 5 | Epoch time: 90.79s | ETA: 0:59:00
# 938/938 [==============================] - 2s 3ms/step
# Epoch 12/50 | Fold 5 | Epoch time: 105.00s | ETA: 1:06:29
# 938/938 [==============================] - 3s 3ms/step
# Epoch 13/50 | Fold 5 | Epoch time: 105.95s | ETA: 1:05:20
# 938/938 [==============================] - 3s 3ms/step
# Epoch 14/50 | Fold 5 | Epoch time: 103.85s | ETA: 1:02:18
# 938/938 [==============================] - 3s 3ms/step
# Epoch 15/50 | Fold 5 | Epoch time: 109.22s | ETA: 1:03:42
# 938/938 [==============================] - 3s 3ms/step
# Epoch 16/50 | Fold 5 | Epoch time: 105.01s | ETA: 0:59:30
# 938/938 [==============================] - 2s 3ms/step
# Epoch 17/50 | Fold 5 | Epoch time: 105.41s | ETA: 0:57:58
# 938/938 [==============================] - 3s 3ms/step
# Epoch 18/50 | Fold 5 | Epoch time: 106.63s | ETA: 0:56:52
# 938/938 [==============================] - 2s 3ms/step
# Epoch 19/50 | Fold 5 | Epoch time: 98.97s | ETA: 0:51:08
# 938/938 [==============================] - 3s 3ms/step
# Epoch 20/50 | Fold 5 | Epoch time: 105.89s | ETA: 0:52:56
# 938/938 [==============================] - 3s 3ms/step
# Epoch 21/50 | Fold 5 | Epoch time: 100.25s | ETA: 0:48:27
# 938/938 [==============================] - 3s 3ms/step
# Epoch 22/50 | Fold 5 | Epoch time: 96.68s | ETA: 0:45:07
# 938/938 [==============================] - 3s 3ms/step
# Epoch 23/50 | Fold 5 | Epoch time: 105.35s | ETA: 0:47:24
# 938/938 [==============================] - 3s 3ms/step
# Epoch 24/50 | Fold 5 | Epoch time: 104.66s | ETA: 0:45:21
# 938/938 [==============================] - 2s 2ms/step
# Epoch 25/50 | Fold 5 | Epoch time: 102.78s | ETA: 0:42:49
# 938/938 [==============================] - 3s 3ms/step
# Epoch 26/50 | Fold 5 | Epoch time: 102.16s | ETA: 0:40:51
# 938/938 [==============================] - 2s 3ms/step
# Epoch 27/50 | Fold 5 | Epoch time: 105.10s | ETA: 0:40:17
# 938/938 [==============================] - 2s 3ms/step
# Epoch 28/50 | Fold 5 | Epoch time: 99.74s | ETA: 0:36:34
# 938/938 [==============================] - 2s 3ms/step
# Epoch 29/50 | Fold 5 | Epoch time: 91.49s | ETA: 0:32:01
# 938/938 [==============================] - 2s 3ms/step
# Epoch 30/50 | Fold 5 | Epoch time: 105.64s | ETA: 0:35:12
# 938/938 [==============================] - 2s 3ms/step
# Epoch 31/50 | Fold 5 | Epoch time: 105.49s | ETA: 0:33:24
# 938/938 [==============================] - 2s 3ms/step
# Epoch 32/50 | Fold 5 | Epoch time: 104.51s | ETA: 0:31:21
# 938/938 [==============================] - 3s 3ms/step
# Epoch 33/50 | Fold 5 | Epoch time: 103.33s | ETA: 0:29:16
# 938/938 [==============================] - 2s 3ms/step
# Epoch 34/50 | Fold 5 | Epoch time: 105.10s | ETA: 0:28:01
# 938/938 [==============================] - 3s 3ms/step
# Epoch 35/50 | Fold 5 | Epoch time: 105.15s | ETA: 0:26:17
# 938/938 [==============================] - 3s 3ms/step
# Epoch 36/50 | Fold 5 | Epoch time: 100.32s | ETA: 0:23:24
# 938/938 [==============================] - 3s 3ms/step
# Epoch 37/50 | Fold 5 | Epoch time: 98.29s | ETA: 0:21:17
# 938/938 [==============================] - 3s 3ms/step
# Epoch 38/50 | Fold 5 | Epoch time: 93.84s | ETA: 0:18:46
# 938/938 [==============================] - 3s 3ms/step
# Epoch 39/50 | Fold 5 | Epoch time: 92.51s | ETA: 0:16:57
# 938/938 [==============================] - 2s 3ms/step
# Epoch 40/50 | Fold 5 | Epoch time: 97.06s | ETA: 0:16:10
# 938/938 [==============================] - 2s 3ms/step
# Epoch 41/50 | Fold 5 | Epoch time: 57.16s | ETA: 0:08:34
# 938/938 [==============================] - 3s 3ms/step
# Epoch 42/50 | Fold 5 | Epoch time: 83.42s | ETA: 0:11:07
# 938/938 [==============================] - 3s 3ms/step
# Epoch 43/50 | Fold 5 | Epoch time: 87.00s | ETA: 0:10:08
# 938/938 [==============================] - 3s 3ms/step
# Epoch 44/50 | Fold 5 | Epoch time: 105.71s | ETA: 0:10:34
# 938/938 [==============================] - 3s 3ms/step
# Epoch 45/50 | Fold 5 | Epoch time: 105.60s | ETA: 0:08:48
# 938/938 [==============================] - 3s 3ms/step
# Epoch 46/50 | Fold 5 | Epoch time: 105.48s | ETA: 0:07:01
# 938/938 [==============================] - 2s 3ms/step
# Epoch 47/50 | Fold 5 | Epoch time: 99.66s | ETA: 0:04:58
# 938/938 [==============================] - 3s 3ms/step
# Epoch 48/50 | Fold 5 | Epoch time: 105.14s | ETA: 0:03:30
# 938/938 [==============================] - 3s 3ms/step
# Epoch 49/50 | Fold
# 904/904 [==============================] - 3s 3ms/step
# Epoch 8/50 | Fold 1 | Epoch time: 81.36s | ETA: 0:56:57
# 904/904 [==============================] - 3s 3ms/step
# Epoch 9/50 | Fold 1 | Epoch time: 91.72s | ETA: 1:02:40
# 904/904 [==============================] - 3s 3ms/step
# Epoch 10/50 | Fold 1 | Epoch time: 91.24s | ETA: 1:00:49
# 904/904 [==============================] - 3s 3ms/step
# Epoch 11/50 | Fold 1 | Epoch time: 91.33s | ETA: 0:59:22
# 904/904 [==============================] - 3s 3ms/step
# Epoch 12/50 | Fold 1 | Epoch time: 87.70s | ETA: 0:55:32
# 904/904 [==============================] - 3s 3ms/step
# Epoch 13/50 | Fold 1 | Epoch time: 90.62s | ETA: 0:55:52
# 904/904 [==============================] - 3s 3ms/step
# Epoch 14/50 | Fold 1 | Epoch time: 91.34s | ETA: 0:54:48
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[204], line 52
#      49 epoch_start = time.time()
#      51 # Train the model for one epoch
# ---> 52 model.fit(x_train,
#      53           y_train,
#      54           batch_size=batch_size,
#      55           epochs=1,  # Train one epoch at a time
#      56           verbose=0,
#      57           shuffle=True,
#      58           validation_data=(x_val, y_val),
#      59           callbacks=[early_stopping, tensorboard])  # Added TensorBoard and EarlyStopping callbacks
#      61 # Save weights after each epoch
#      62 model.save_weights((checkpoint_dir / f'ckpt_{fold}_{epoch}').as_posix())
#
# File c:\Users\flyin\.conda\envs\py311\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\flyin\.conda\envs\py311\lib\site-packages\keras\engine\training.py:1555, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1551 with data_handler.catch_stop_iteration():
#    1552     data_handler._initial_step = data_handler._initial_step or (
#    1553         self._maybe_load_initial_step_from_ckpt()
#    1554     )
# -> 1555     for step in data_handler.steps():
#    1556         with tf.profiler.experimental.Trace(
#    1557             "train",
#    1558             epoch_num=epoch,
#    (...)
#    1561             _r=1,
#    1562         ):
#    1563             callbacks.on_train_batch_begin(step)
#
# File c:\Users\flyin\.conda\envs\py311\lib\site-packages\keras\engine\data_adapter.py:1374, in DataHandler.steps(self)
#    1372 if self._insufficient_data:  # Set by `catch_stop_iteration`.
#    1373     break
# -> 1374 original_spe = self._steps_per_execution.numpy().item()
#    1375 can_run_full_execution = (
#    1376     original_spe == 1
#    1377     or self._inferred_steps is None
#    1378     or self._inferred_steps - self._current_step >= original_spe
#    1379 )
#    1381 if can_run_full_execution:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\ops\resource_variable_ops.py:637, in BaseResourceVariable.numpy(self)
#     635 def numpy(self):
#     636   if context.executing_eagerly():
# --> 637     return self.read_value().numpy()
#     638   raise NotImplementedError(
#     639       "numpy() is only available when eager execution is enabled.")
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\framework\ops.py:1157, in _EagerTensorBase.numpy(self)
#    1134 """Copy of the contents of this Tensor into a NumPy array or scalar.
#    1135
#    1136 Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#    1154     NumPy dtype.
#    1155 """
#    1156 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1157 maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1158 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File ~\AppData\Roaming\Python\Python310\site-packages\tensorflow\python\framework\ops.py:1123, in _EagerTensorBase._numpy(self)
#    1121 def _numpy(self):
#    1122   try:
# -> 1123     return self._numpy_internal()
#    1124   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1125     raise core._status_to_exception(e) from None
#
# KeyboardInterrupt:

# %% [markdown]
# ### Evaluate predictive performance

# %%
params = ['dense_layers', 'dropout', 'batch_size']

# %%
ic = pd.read_hdf(results_path / 'scores.h5', 'ic_by_day').drop('activation', axis=1)
ic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 252 entries, 2014-09-30 to 2014-12-29
# Data columns (total 54 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   0             252 non-null    float64
#  1   1             252 non-null    float64
#  2   2             252 non-null    float64
#  3   3             252 non-null    float64
#  4   4             252 non-null    float64
#  5   5             252 non-null    float64
#  6   6             252 non-null    float64
#  7   7             252 non-null    float64
#  8   8             252 non-null    float64
#  9   9             252 non-null    float64
#  10  10            252 non-null    float64
#  11  11            252 non-null    float64
#  12  12            252 non-null    float64
#  13  13            252 non-null    float64
#  14  14            252 non-null    float64
#  15  15            252 non-null    float64
#  16  16            252 non-null    float64
#  17  17            252 non-null    float64
#  18  18            252 non-null    float64
#  19  19            252 non-null    float64
#  20  20            252 non-null    float64
#  21  21            252 non-null    float64
#  22  22            252 non-null    float64
#  23  23            252 non-null    float64
#  24  24            252 non-null    float64
#  25  25            251 non-null    float64
#  26  26            252 non-null    float64
#  27  27            252 non-null    float64
#  28  28            252 non-null    float64
#  29  29            252 non-null    float64
#  30  30            252 non-null    float64
#  31  31            251 non-null    float64
#  32  32            248 non-null    float64
#  33  33            219 non-null    float64
#  34  34            230 non-null    float64
#  35  35            240 non-null    float64
#  36  36            235 non-null    float64
#  37  37            216 non-null    float64
#  38  38            214 non-null    float64
#  39  39            208 non-null    float64
#  40  40            225 non-null    float64
#  41  41            231 non-null    float64
#  42  42            206 non-null    float64
#  43  43            205 non-null    float64
#  44  44            189 non-null    float64
#  45  45            191 non-null    float64
#  46  46            203 non-null    float64
#  47  47            202 non-null    float64
#  48  48            190 non-null    float64
#  49  49            187 non-null    float64
#  50  dense_layers  252 non-null    object
#  51  dropout       252 non-null    float64
#  52  batch_size    252 non-null    int64
#  53  fold          252 non-null    int64
# dtypes: float64(51), int64(2), object(1)
# memory usage: 108.3+ KB

# %%
ic.groupby(params).size()
# Out:
# dense_layers  dropout  batch_size
# (64, 32)      0.0      64            63
#                        256           63
#               0.1      64            63
#                        256           63
# dtype: int64

# %%
ic_long = pd.melt(ic, id_vars=params + ['fold'], var_name='epoch', value_name='ic')
ic_long.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12600 entries, 0 to 12599
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   dense_layers  12600 non-null  object
#  1   dropout       12600 non-null  float64
#  2   batch_size    12600 non-null  int64
#  3   fold          12600 non-null  int64
#  4   epoch         12600 non-null  object
#  5   ic            11901 non-null  float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 590.8+ KB

# %%
ic_long = ic_long.groupby(params+ ['epoch', 'fold']).ic.mean().to_frame('ic').reset_index()

# %%
g = sns.relplot(x='epoch', y='ic', col='dense_layers', row='dropout', 
                data=ic_long[ic_long.dropout>0], kind='line')
g.map(plt.axhline, y=0, ls='--', c='k', lw=1)
g.savefig(results_path / 'ic_lineplot', dpi=300);

# %%
def run_ols(ic):
    ic.dense_layers = ic.dense_layers.str.replace(', ', '-').str.replace('(', '').str.replace(')', '')
    data = pd.melt(ic, id_vars=params, var_name='epoch', value_name='ic')
    data.epoch = data.epoch.astype(int).astype(str).apply(lambda x: f'{int(x):02.0f}')
    model_data = pd.get_dummies(data.sort_values(params + ['epoch']), columns=['epoch'] + params, drop_first=True).sort_index(1)
    model_data.columns = [s.split('_')[-1] for s in model_data.columns]
    model = sm.OLS(endog=model_data.ic, exog=sm.add_constant(model_data.drop('ic', axis=1)))
    return model.fit()

# %%
model = run_ols(ic.drop('fold', axis=1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[212], line 1
# ----> 1 model = run_ols(ic.drop('fold', axis=1))
#
# Cell In[211], line 5, in run_ols(ic)
#       3 data = pd.melt(ic, id_vars=params, var_name='epoch', value_name='ic')
#       4 data.epoch = data.epoch.astype(int).astype(str).apply(lambda x: f'{int(x):02.0f}')
# ----> 5 model_data = pd.get_dummies(data.sort_values(params + ['epoch']), columns=['epoch'] + params, drop_first=True).sort_index(1)
#       6 model_data.columns = [s.split('_')[-1] for s in model_data.columns]
#       7 model = sm.OLS(endog=model_data.ic, exog=sm.add_constant(model_data.drop('ic', axis=1)))
#
# TypeError: DataFrame.sort_index() takes 1 positional argument but 2 were given

# %%
print(model.summary())
# Out:
# Model: "sequential_65"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_166 (Conv1D)         (None, 43, 32)            128
#
#  batch_normalization_165 (Ba  (None, 43, 32)           128
#  tchNormalization)
#
#  activation_279 (Activation)  (None, 43, 32)           0
#
#  max_pooling1d_165 (MaxPooli  (None, 21, 32)           0
#  ng1D)
#
#  dropout_277 (Dropout)       (None, 21, 32)            0
#
#  conv1d_167 (Conv1D)         (None, 21, 64)            6208
#
#  batch_normalization_166 (Ba  (None, 21, 64)           256
#  tchNormalization)
#
#  activation_280 (Activation)  (None, 21, 64)           0
#
#  max_pooling1d_166 (MaxPooli  (None, 10, 64)           0
#  ng1D)
#
#  dropout_278 (Dropout)       (None, 10, 64)            0
#
#  conv1d_168 (Conv1D)         (None, 10, 128)           24704
#
#  batch_normalization_167 (Ba  (None, 10, 128)          512
#  tchNormalization)
#
#  activation_281 (Activation)  (None, 10, 128)          0
#
#  max_pooling1d_167 (MaxPooli  (None, 5, 128)           0
#  ng1D)
#
#  dropout_279 (Dropout)       (None, 5, 128)            0
#
#  global_average_pooling1d_55  (None, 128)              0
#   (GlobalAveragePooling1D)
#
#  dense_172 (Dense)           (None, 16)                2064
#
#  activation_282 (Activation)  (None, 16)               0
#
#  dropout_280 (Dropout)       (None, 16)                0
#
#  dense_173 (Dense)           (None, 8)                 136
#
#  activation_283 (Activation)  (None, 8)                0
#
#  dropout_281 (Dropout)       (None, 8)                 0
#
#  dense_174 (Dense)           (None, 1)                 9
#
# =================================================================
# Total params: 34,145
# Trainable params: 33,697
# Non-trainable params: 448
# _________________________________________________________________
# None

# %%
fig, ax = plt.subplots(figsize=(14, 4))

ci = model.conf_int()
errors = ci[1].sub(ci[0]).div(2)

coefs = (model.params.to_frame('coef').assign(error=errors)
         .reset_index().rename(columns={'index': 'variable'}))
coefs = coefs[~coefs['variable'].str.startswith('date') & (coefs.variable != 'const')]

coefs.plot(x='variable', y='coef', kind='bar',
           ax=ax, color='none', capsize=3,
           yerr='error', legend=False, rot=0, title='Impact of Architecture and Training Parameters on Out-of-Sample Performance')
ax.set_ylabel('IC')
ax.set_xlabel('')
ax.scatter(x=pd.np.arange(len(coefs)), marker='_', s=120, y=coefs['coef'], color='black')
ax.axhline(y=0, linestyle='--', color='black', linewidth=1)
ax.xaxis.set_ticks_position('none')

ax.annotate('Batch Size', xy=(.02, -0.1), xytext=(.02, -0.2),
            xycoords='axes fraction',
            textcoords='axes fraction',
            fontsize=11, ha='center', va='bottom',
            bbox=dict(boxstyle='square', fc='white', ec='black'),
            arrowprops=dict(arrowstyle='-[, widthB=1.3, lengthB=0.8', lw=1.0, color='black'))

ax.annotate('Layers', xy=(.1, -0.1), xytext=(.1, -0.2),
            xycoords='axes fraction',
            textcoords='axes fraction',
            fontsize=11, ha='center', va='bottom',
            bbox=dict(boxstyle='square', fc='white', ec='black'),
            arrowprops=dict(arrowstyle='-[, widthB=4.8, lengthB=0.8', lw=1.0, color='black'))

ax.annotate('Dropout', xy=(.2, -0.1), xytext=(.2, -0.2),
            xycoords='axes fraction',
            textcoords='axes fraction',
            fontsize=11, ha='center', va='bottom',
            bbox=dict(boxstyle='square', fc='white', ec='black'),
            arrowprops=dict(arrowstyle='-[, widthB=2.8, lengthB=0.8', lw=1.0, color='black'))

ax.annotate('Epochs', xy=(.62, -0.1), xytext=(.62, -0.2),
            xycoords='axes fraction',
            textcoords='axes fraction',
            fontsize=11, ha='center', va='bottom',
            bbox=dict(boxstyle='square', fc='white', ec='black'),
            arrowprops=dict(arrowstyle='-[, widthB=30.5, lengthB=1.0', lw=1.0, color='black'))

sns.despine()
fig.tight_layout()
fig.savefig(results_path / 'ols_coef', dpi=300)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[214], line 3
#       1 fig, ax = plt.subplots(figsize=(14, 4))
# ----> 3 ci = model.conf_int()
#       4 errors = ci[1].sub(ci[0]).div(2)
#       6 coefs = (model.params.to_frame('coef').assign(error=errors)
#       7          .reset_index().rename(columns={'index': 'variable'}))
#
# AttributeError: 'Sequential' object has no attribute 'conf_int'

# %% [markdown]
# ## Make Predictions

# %%
def get_best_params(n=5):
    """Get the best parameters across all folds by daily median IC"""
    params = ['dense_layers', 'activation', 'dropout', 'batch_size']
    ic = pd.read_hdf(results_path / 'scores.h5', 'ic_by_day').drop('fold', axis=1)
    dates = sorted(ic.index.unique())
    train_period = 24 * 21
    train_dates = dates[:train_period]
    ic = ic.loc[train_dates]
    return (ic.groupby(params)
            .median()
            .stack()
            .to_frame('ic')
            .reset_index()
            .rename(columns={'level_4': 'epoch'})
            .nlargest(n=n, columns='ic')
            .drop('ic', axis=1)
            .to_dict('records'))

# %%
def generate_predictions(dense_layers, activation, dropout, batch_size, epoch):
    data = pd.read_hdf('../12_gradient_boosting_machines/data.h5', 'model_data').dropna().sort_index()
    outcomes = data.filter(like='fwd').columns.tolist()
    X_cv = data.loc[idx[:, :'2017'], :].drop(outcomes, axis=1)
    input_dim = X_cv.shape[1]
    y_cv = data.loc[idx[:, :'2017'], 'r01_fwd']

    scaler = StandardScaler()
    predictions = []
    
    do = '0' if str(dropout) == '0.0' else str(dropout)
    checkpoint_dir = checkpoint_path / str(dense_layers) / activation / str(do) / str(batch_size)
        
    for fold, (train_idx, test_idx) in enumerate(cv.split(X_cv)):
        x_train, y_train, x_val, y_val = get_train_valid_data(X_cv, y_cv, train_idx, test_idx)
        x_val = scaler.fit(x_train).transform(x_val)
        model = make_model(make_tuple(dense_layers), activation, dropout)
        status = model.load_weights((checkpoint_dir / f'ckpt_{fold}_{epoch}').as_posix())
        status.expect_partial()
        predictions.append(pd.Series(model.predict(x_val).squeeze(), index=y_val.index))
    return pd.concat(predictions)

# %%
best_params = get_best_params()
predictions = []
for i, params in enumerate(best_params):
    predictions.append(generate_predictions(**params).to_frame(i))

predictions = pd.concat(predictions, axis=1)
print(predictions.info())
predictions.to_hdf(results_path / 'test_preds.h5', 'predictions')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[217], line 4
#       2 predictions = []
#       3 for i, params in enumerate(best_params):
# ----> 4     predictions.append(generate_predictions(**params).to_frame(i))
#       6 predictions = pd.concat(predictions, axis=1)
#       7 print(predictions.info())
#
# Cell In[216], line 2, in generate_predictions(dense_layers, activation, dropout, batch_size, epoch)
#       1 def generate_predictions(dense_layers, activation, dropout, batch_size, epoch):
# ----> 2     data = pd.read_hdf('../12_gradient_boosting_machines/data.h5', 'model_data').dropna().sort_index()
#       3     outcomes = data.filter(like='fwd').columns.tolist()
#       4     X_cv = data.loc[idx[:, :'2017'], :].drop(outcomes, axis=1)
#
# File c:\Users\flyin\.conda\envs\py311\lib\site-packages\pandas\io\pytables.py:424, in read_hdf(path_or_buf, key, mode, errors, where, start, stop, columns, iterator, chunksize, **kwargs)
#     421     exists = False
#     423 if not exists:
# --> 424     raise FileNotFoundError(f"File {path_or_buf} does not exist")
#     426 store = HDFStore(path_or_buf, mode=mode, errors=errors, **kwargs)
#     427 # can't auto open/close if we are using an iterator
#     428 # so delegate to the iterator
#
# FileNotFoundError: File ../12_gradient_boosting_machines/data.h5 does not exist

# %% [markdown]
# ### How to further improve the results
#
# The relatively simple architecture yields some promising results. To further improve performance, you can
# - First and foremost, add new features and more data to the model
# - Expand the set of architectures to explore, including more or wider layers
# - Inspect the training progress and train for more epochs if the validation error continued to improve at 50 epochs
#
# Finally, you can use more sophisticated architectures, including Recurrent Neural Networks (RNN) and Convolutional Neural Networks that are well suited to sequential data, whereas vanilla feedforward NNs are not designed to capture the ordered nature of the features.
